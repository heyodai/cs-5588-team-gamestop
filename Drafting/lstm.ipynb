# %%
# !pip install yfinance numpy tensorflow ta
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.44)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: ta in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.5)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.2)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import ta
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Function to download data and add technical indicators
def download_and_structure(ticker):
    start_date = "2018-01-01"
    end_date = "2021-12-31"

    # Download data
    data = yf.download(ticker, start=start_date, end=end_date)
    data = data.reset_index(drop=False)

    # Create the target: next day's closing price
    data['target'] = data['Close'].shift(-1)

    # Adding technical indicators
    data['MA30'] = data['Close'].rolling(window=30).mean()
    data['MA7'] = data['Close'].rolling(window=7).mean()
    data['RSI'] = ta.momentum.RSIIndicator(data['Close']).rsi()
    data['EMA50'] = data['Close'].ewm(span=50, adjust=False).mean()
    data['MACD'] = ta.trend.MACD(data['Close']).macd_diff()
    data['Bollinger_High'] = ta.volatility.BollingerBands(data['Close']).bollinger_hband()
    data['Bollinger_Low'] = ta.volatility.BollingerBands(data['Close']).bollinger_lband()
    data['Stochastic_Oscillator'] = ta.momentum.StochasticOscillator(data['High'], data['Low'], data['Close']).stoch()
    data['Williams_R'] = ta.momentum.WilliamsRIndicator(data['High'], data['Low'], data['Close']).williams_r()
    data['OBV'] = ta.volume.OnBalanceVolumeIndicator(data['Close'], data['Volume']).on_balance_volume()

    # Drop rows with missing values
    data = data.dropna()

    return data

# Prepare data for LSTM with feature scaling and creating sequences
def prepare_data(df, n_steps):
    features = df[['Open', 'High', 'Low', 'Close', 'Volume', 'MA30', 'MA7', 'RSI', 'EMA50', 'MACD', 'Bollinger_High', 'Bollinger_Low', 'Stochastic_Oscillator', 'Williams_R', 'OBV']].values
    targets = df['target'].values

    # Scale the features and target
    scaler_features = MinMaxScaler(feature_range=(0, 1))
    features_scaled = scaler_features.fit_transform(features)

    scaler_target = MinMaxScaler(feature_range=(0, 1))
    targets_scaled = scaler_target.fit_transform(targets.reshape(-1, 1))

    # Create sequences for LSTM model
    x, y = [], []
    for i in range(len(features_scaled) - n_steps):
        x.append(features_scaled[i:i + n_steps])
        y.append(targets_scaled[i + n_steps])

    return np.array(x), np.array(y), scaler_features, scaler_target

# Create an LSTM model with more complexity (more layers and units)
def create_lstm_model(input_shape):
    model = Sequential()

    model.add(Input(shape=input_shape))

    # Add multiple LSTM layers with more units
    model.add(Bidirectional(LSTM(units=128, return_sequences=True)))
    model.add(Dropout(0.3))

    model.add(Bidirectional(LSTM(units=64, return_sequences=True)))
    model.add(Dropout(0.3))

    model.add(Bidirectional(LSTM(units=32, return_sequences=False)))
    model.add(Dropout(0.3))

    # Dense output layer with linear activation
    model.add(Dense(units=1, activation='linear'))

    # Compile the model
    optimizer = RMSprop(learning_rate=0.0001)  # Reduced learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

    return model

# %%
# Train and evaluate the model using TimeSeriesSplit and a longer sequence length (n_steps)
def train_and_evaluate(ticker, n_steps=120, test_size=0.2):
    # Download and preprocess the data
    df = download_and_structure(ticker)

    # Prepare the data for the LSTM model
    x, y, scaler_features, scaler_target = prepare_data(df, n_steps)

    # TimeSeriesSplit for rolling cross-validation
    tscv = TimeSeriesSplit(n_splits=5)
    for train_index, test_index in tscv.split(x):
        x_train, x_test = x[train_index], x[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Reshape input data to fit LSTM [samples, time steps, features]
        x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], x_train.shape[2]))
        x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], x_test.shape[2]))

        # Create and compile the LSTM model with increased complexity
        model = create_lstm_model((x_train.shape[1], x_train.shape[2]))

        # Early stopping and learning rate reduction
        early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

        # Train the model with validation split and callbacks
        model.fit(x_train, y_train, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stop, lr_scheduler])

        # Make predictions on the test data
        y_pred = model.predict(x_test)

        # Inverse transform the predictions and actual values
        y_pred_rescaled = scaler_target.inverse_transform(y_pred)
        y_test_rescaled = scaler_target.inverse_transform(y_test)

        # Evaluate the model performance with RMSE and MAE
        rmse = np.sqrt(np.mean((y_pred_rescaled - y_test_rescaled) ** 2))
        mae = np.mean(np.abs(y_pred_rescaled - y_test_rescaled))

        print(f"RMSE: {rmse:.2f}")
        print(f"MAE: {mae:.2f}")

    return model, scaler_features, scaler_target, df

# %%
df = download_and_structure('AAPL')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#          Date       Open       High        Low      Close  Adj Close  \
# 33 2018-02-20  43.012501  43.564999  42.855000  42.962502  40.637375
# 34 2018-02-21  43.207500  43.529999  42.752499  42.767502  40.452927
# 35 2018-02-22  42.950001  43.487499  42.927502  43.125000  40.791092
# 36 2018-02-23  43.417500  43.912498  43.384998  43.875000  41.500496
# 37 2018-02-26  44.087502  44.847500  44.052502  44.742500  42.321056
#
#        Volume     target       MA30        MA7        RSI      EMA50  \
# 33  135722000  42.767502  42.434833  41.717857  56.099084  42.391802
# 34  149886400  43.125000  42.407500  42.241429  54.722385  42.406535
# 35  123967600  43.875000  42.392250  42.591072  56.814776  42.434710
# 36  135249600  44.742500  42.402333  42.989643  60.897380  42.491192
# 37  152648800  44.597500  42.433083  43.403929  65.016959  42.579479
#
#         MACD  Bollinger_High  Bollinger_Low  Stochastic_Oscillator  \
# 33  0.425262       44.696650      38.474099              87.917002
# 34  0.414815       44.427344      38.594156              84.743695
# 35  0.414142       44.351075      38.627425              90.561403
# 36  0.443735       44.541530      38.546720              99.409705
# 37  0.497234       44.899276      38.375474              98.559183
#
#     Williams_R        OBV
# 33  -12.082998 -226217600
# 34  -15.256305 -376104000
# 35   -9.438597 -252136400
# 36   -0.590295 -116886800
# 37   -1.440817   35762000

# %%
# Function to predict stock price for specific dates
def predict_for_dates(model, scaler_features, scaler_target, df, dates, n_steps=120):
    df['Date'] = pd.to_datetime(df['Date'])

    @tf.function(reduce_retracing=True)
    def model_predict(features_scaled):
        return model(features_scaled)

    for date_str in dates:
        date = pd.to_datetime(date_str)

        if date not in df['Date'].values:
            print(f"Date {date_str} is not in the available data range.")
            continue

        data_until_date = df[df['Date'] <= date].tail(n_steps)

        if len(data_until_date) < n_steps:
            print(f"Not enough historical data available up to {date_str} to make a prediction.")
            continue

        features = data_until_date[['Open', 'High', 'Low', 'Close', 'Volume', 'MA30', 'MA7', 'RSI', 'EMA50', 'MACD', 'Bollinger_High', 'Bollinger_Low', 'Stochastic_Oscillator', 'Williams_R', 'OBV']].values
        features_scaled = scaler_features.transform(features)
        features_scaled = np.reshape(features_scaled, (1, features_scaled.shape[0], features_scaled.shape[1]))

        predicted_price_scaled = model_predict(features_scaled)
        predicted_price = scaler_target.inverse_transform(predicted_price_scaled)

        print(f"Predicted closing price for {date_str}: {predicted_price[0][0]:.2f}")

# %%
model, scaler_features, scaler_target, df = train_and_evaluate('AAPL', n_steps=80)
predict_for_dates(model, scaler_features, scaler_target, df, ['2020-12-31', '2021-12-01'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 483ms/step - loss: 0.0117 - mae: 0.0873 - val_loss: 3.4726e-04 - val_mae: 0.0139 - learning_rate: 1.0000e-04
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0049 - mae: 0.0560 - val_loss: 4.0012e-04 - val_mae: 0.0155 - learning_rate: 1.0000e-04
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0044 - mae: 0.0522 - val_loss: 4.1104e-04 - val_mae: 0.0160 - learning_rate: 1.0000e-04
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0043 - mae: 0.0535 - val_loss: 2.6084e-04 - val_mae: 0.0125 - learning_rate: 1.0000e-04
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0042 - mae: 0.0516 - val_loss: 2.8967e-04 - val_mae: 0.0133 - learning_rate: 5.0000e-05
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0029 - mae: 0.0429 - val_loss: 4.1907e-04 - val_mae: 0.0165 - learning_rate: 5.0000e-05
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0031 - mae: 0.0453 - val_loss: 5.6100e-04 - val_mae: 0.0196 - learning_rate: 5.0000e-05
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0038 - mae: 0.0498 - val_loss: 5.2299e-04 - val_mae: 0.0188 - learning_rate: 2.5000e-05
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0042 - mae: 0.0530 - val_loss: 3.9787e-04 - val_mae: 0.0161 - learning_rate: 2.5000e-05
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0034 - mae: 0.0469 - val_loss: 5.7780e-04 - val_mae: 0.0201 - learning_rate: 2.5000e-05
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0033 - mae: 0.0478 - val_loss: 5.0206e-04 - val_mae: 0.0184 - learning_rate: 1.2500e-05
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0036 - mae: 0.0484 - val_loss: 4.8699e-04 - val_mae: 0.0181 - learning_rate: 1.2500e-05
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0039 - mae: 0.0490 - val_loss: 4.5405e-04 - val_mae: 0.0174 - learning_rate: 1.2500e-05
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0030 - mae: 0.0449 - val_loss: 4.7439e-04 - val_mae: 0.0179 - learning_rate: 6.2500e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# RMSE: 3.87
# MAE: 3.12
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - loss: 0.0073 - mae: 0.0694 - val_loss: 0.0013 - val_mae: 0.0331 - learning_rate: 1.0000e-04
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0043 - mae: 0.0512 - val_loss: 0.0018 - val_mae: 0.0378 - learning_rate: 1.0000e-04
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0042 - mae: 0.0529 - val_loss: 5.7093e-04 - val_mae: 0.0214 - learning_rate: 1.0000e-04
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0035 - mae: 0.0467 - val_loss: 6.2608e-04 - val_mae: 0.0165 - learning_rate: 1.0000e-04
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0032 - mae: 0.0426 - val_loss: 0.0010 - val_mae: 0.0290 - learning_rate: 1.0000e-04
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0022 - mae: 0.0366 - val_loss: 9.1544e-04 - val_mae: 0.0275 - learning_rate: 1.0000e-04
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0031 - mae: 0.0457 - val_loss: 0.0010 - val_mae: 0.0293 - learning_rate: 5.0000e-05
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0023 - mae: 0.0378 - val_loss: 4.7512e-04 - val_mae: 0.0182 - learning_rate: 5.0000e-05
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0021 - mae: 0.0363 - val_loss: 7.1833e-04 - val_mae: 0.0243 - learning_rate: 5.0000e-05
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0023 - mae: 0.0389 - val_loss: 8.7209e-04 - val_mae: 0.0270 - learning_rate: 2.5000e-05
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0020 - mae: 0.0352 - val_loss: 7.6290e-04 - val_mae: 0.0251 - learning_rate: 2.5000e-05
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0021 - mae: 0.0363 - val_loss: 6.6645e-04 - val_mae: 0.0234 - learning_rate: 2.5000e-05
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0016 - mae: 0.0333 - val_loss: 6.9690e-04 - val_mae: 0.0240 - learning_rate: 1.2500e-05
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0017 - mae: 0.0324 - val_loss: 7.0251e-04 - val_mae: 0.0241 - learning_rate: 1.2500e-05
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0019 - mae: 0.0357 - val_loss: 6.8276e-04 - val_mae: 0.0237 - learning_rate: 1.2500e-05
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0015 - mae: 0.0310 - val_loss: 6.8226e-04 - val_mae: 0.0237 - learning_rate: 6.2500e-06
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0021 - mae: 0.0349 - val_loss: 5.9605e-04 - val_mae: 0.0221 - learning_rate: 6.2500e-06
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0019 - mae: 0.0333 - val_loss: 6.4432e-04 - val_mae: 0.0230 - learning_rate: 6.2500e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
# RMSE: 15.81
# MAE: 14.36
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 166ms/step - loss: 0.0096 - mae: 0.0788 - val_loss: 0.0311 - val_mae: 0.1731 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0046 - mae: 0.0528 - val_loss: 0.0272 - val_mae: 0.1616 - learning_rate: 1.0000e-04
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0033 - mae: 0.0460 - val_loss: 0.0216 - val_mae: 0.1435 - learning_rate: 1.0000e-04
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0030 - mae: 0.0433 - val_loss: 0.0218 - val_mae: 0.1445 - learning_rate: 1.0000e-04
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0026 - mae: 0.0410 - val_loss: 0.0224 - val_mae: 0.1464 - learning_rate: 1.0000e-04
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0023 - mae: 0.0380 - val_loss: 0.0170 - val_mae: 0.1267 - learning_rate: 1.0000e-04
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0024 - mae: 0.0383 - val_loss: 0.0106 - val_mae: 0.0991 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0021 - mae: 0.0350 - val_loss: 0.0153 - val_mae: 0.1205 - learning_rate: 1.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0019 - mae: 0.0349 - val_loss: 0.0068 - val_mae: 0.0781 - learning_rate: 1.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0146 - val_mae: 0.1174 - learning_rate: 1.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0060 - val_mae: 0.0734 - learning_rate: 1.0000e-04
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0017 - mae: 0.0325 - val_loss: 0.0176 - val_mae: 0.1296 - learning_rate: 1.0000e-04
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0017 - mae: 0.0328 - val_loss: 0.0077 - val_mae: 0.0842 - learning_rate: 1.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0015 - mae: 0.0302 - val_loss: 0.0076 - val_mae: 0.0836 - learning_rate: 1.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0014 - mae: 0.0308 - val_loss: 0.0102 - val_mae: 0.0978 - learning_rate: 5.0000e-05
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0015 - mae: 0.0309 - val_loss: 0.0066 - val_mae: 0.0773 - learning_rate: 5.0000e-05
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0015 - mae: 0.0311 - val_loss: 0.0092 - val_mae: 0.0926 - learning_rate: 5.0000e-05
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0013 - mae: 0.0279 - val_loss: 0.0073 - val_mae: 0.0819 - learning_rate: 2.5000e-05
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0013 - mae: 0.0279 - val_loss: 0.0069 - val_mae: 0.0793 - learning_rate: 2.5000e-05
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0013 - mae: 0.0287 - val_loss: 0.0072 - val_mae: 0.0813 - learning_rate: 2.5000e-05
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0013 - mae: 0.0288 - val_loss: 0.0078 - val_mae: 0.0845 - learning_rate: 1.2500e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step
# RMSE: 37.65
# MAE: 34.80
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - loss: 0.0104 - mae: 0.0802 - val_loss: 0.0404 - val_mae: 0.1902 - learning_rate: 1.0000e-04
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0046 - mae: 0.0518 - val_loss: 0.0216 - val_mae: 0.1347 - learning_rate: 1.0000e-04
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0043 - mae: 0.0528 - val_loss: 0.0223 - val_mae: 0.1381 - learning_rate: 1.0000e-04
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0034 - mae: 0.0455 - val_loss: 0.0099 - val_mae: 0.0846 - learning_rate: 1.0000e-04
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0029 - mae: 0.0422 - val_loss: 0.0288 - val_mae: 0.1606 - learning_rate: 1.0000e-04
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0036 - mae: 0.0459 - val_loss: 0.0100 - val_mae: 0.0862 - learning_rate: 1.0000e-04
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0022 - mae: 0.0371 - val_loss: 0.0161 - val_mae: 0.1160 - learning_rate: 1.0000e-04
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0019 - mae: 0.0345 - val_loss: 0.0112 - val_mae: 0.0929 - learning_rate: 5.0000e-05
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0024 - mae: 0.0377 - val_loss: 0.0092 - val_mae: 0.0818 - learning_rate: 5.0000e-05
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0019 - mae: 0.0329 - val_loss: 0.0101 - val_mae: 0.0872 - learning_rate: 5.0000e-05
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0018 - mae: 0.0325 - val_loss: 0.0126 - val_mae: 0.0998 - learning_rate: 5.0000e-05
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0017 - mae: 0.0332 - val_loss: 0.0112 - val_mae: 0.0925 - learning_rate: 5.0000e-05
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0015 - mae: 0.0308 - val_loss: 0.0113 - val_mae: 0.0935 - learning_rate: 2.5000e-05
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0020 - mae: 0.0348 - val_loss: 0.0103 - val_mae: 0.0881 - learning_rate: 2.5000e-05
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0018 - mae: 0.0325 - val_loss: 0.0103 - val_mae: 0.0882 - learning_rate: 2.5000e-05
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0017 - mae: 0.0328 - val_loss: 0.0096 - val_mae: 0.0843 - learning_rate: 1.2500e-05
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0019 - mae: 0.0329 - val_loss: 0.0100 - val_mae: 0.0865 - learning_rate: 1.2500e-05
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0016 - mae: 0.0312 - val_loss: 0.0088 - val_mae: 0.0790 - learning_rate: 1.2500e-05
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0018 - mae: 0.0333 - val_loss: 0.0088 - val_mae: 0.0793 - learning_rate: 1.2500e-05
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0017 - mae: 0.0318 - val_loss: 0.0094 - val_mae: 0.0831 - learning_rate: 1.2500e-05
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0017 - mae: 0.0315 - val_loss: 0.0090 - val_mae: 0.0805 - learning_rate: 1.2500e-05
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0016 - mae: 0.0325 - val_loss: 0.0090 - val_mae: 0.0803 - learning_rate: 6.2500e-06
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0017 - mae: 0.0312 - val_loss: 0.0092 - val_mae: 0.0815 - learning_rate: 6.2500e-06
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0019 - mae: 0.0334 - val_loss: 0.0092 - val_mae: 0.0818 - learning_rate: 6.2500e-06
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0016 - mae: 0.0319 - val_loss: 0.0095 - val_mae: 0.0837 - learning_rate: 3.1250e-06
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0093 - val_mae: 0.0822 - learning_rate: 3.1250e-06
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0091 - val_mae: 0.0811 - learning_rate: 3.1250e-06
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0019 - mae: 0.0331 - val_loss: 0.0090 - val_mae: 0.0807 - learning_rate: 1.5625e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# RMSE: 11.81
# MAE: 10.70
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - loss: 0.0518 - mae: 0.1700 - val_loss: 0.0276 - val_mae: 0.1579 - learning_rate: 1.0000e-04
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0102 - mae: 0.0760 - val_loss: 0.0054 - val_mae: 0.0603 - learning_rate: 1.0000e-04
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0065 - mae: 0.0607 - val_loss: 0.0019 - val_mae: 0.0351 - learning_rate: 1.0000e-04
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0051 - mae: 0.0527 - val_loss: 0.0017 - val_mae: 0.0337 - learning_rate: 1.0000e-04
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0044 - mae: 0.0499 - val_loss: 0.0015 - val_mae: 0.0317 - learning_rate: 1.0000e-04
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0038 - mae: 0.0453 - val_loss: 0.0107 - val_mae: 0.0967 - learning_rate: 1.0000e-04
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0047 - mae: 0.0521 - val_loss: 0.0016 - val_mae: 0.0330 - learning_rate: 1.0000e-04
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0033 - mae: 0.0423 - val_loss: 0.0036 - val_mae: 0.0507 - learning_rate: 1.0000e-04
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0031 - mae: 0.0409 - val_loss: 0.0017 - val_mae: 0.0336 - learning_rate: 5.0000e-05
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0034 - mae: 0.0415 - val_loss: 0.0015 - val_mae: 0.0315 - learning_rate: 5.0000e-05
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0031 - mae: 0.0389 - val_loss: 0.0021 - val_mae: 0.0364 - learning_rate: 5.0000e-05
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0027 - mae: 0.0391 - val_loss: 0.0022 - val_mae: 0.0375 - learning_rate: 2.5000e-05
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0032 - mae: 0.0410 - val_loss: 0.0023 - val_mae: 0.0382 - learning_rate: 2.5000e-05
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0029 - mae: 0.0383 - val_loss: 0.0024 - val_mae: 0.0397 - learning_rate: 2.5000e-05
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0030 - mae: 0.0387 - val_loss: 0.0030 - val_mae: 0.0455 - learning_rate: 1.2500e-05
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0024 - mae: 0.0366 - val_loss: 0.0038 - val_mae: 0.0518 - learning_rate: 1.2500e-05
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0028 - mae: 0.0384 - val_loss: 0.0035 - val_mae: 0.0499 - learning_rate: 1.2500e-05
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0027 - mae: 0.0379 - val_loss: 0.0028 - val_mae: 0.0432 - learning_rate: 6.2500e-06
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0030 - mae: 0.0398 - val_loss: 0.0032 - val_mae: 0.0470 - learning_rate: 6.2500e-06
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0031 - mae: 0.0415 - val_loss: 0.0030 - val_mae: 0.0453 - learning_rate: 6.2500e-06
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# RMSE: 10.75
# MAE: 7.98
# Predicted closing price for 2020-12-31: 125.26
# Predicted closing price for 2021-12-01: 149.13

# %%
df[df['Date'] == '2020-12-31']
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 755 2020-12-31  134.080002  134.740005  131.720001  132.690002  129.894318
#
#        Volume      target     MA30         MA7        RSI      EMA50  \
# 755  99116600  129.410004  124.503  133.254288  62.738934  123.08475
#
#          MACD  Bollinger_High  Bollinger_Low  Stochastic_Oscillator  \
# 755  0.458586      137.100152     118.358848               66.55705
#
#      Williams_R         OBV
# 755   -33.44295  3263368200

# %%
df[df['Date'] == '2021-12-01']
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 986 2021-12-01  167.479996  170.300003  164.529999  164.770004  162.292801
#
#         Volume      target        MA30         MA7        RSI       EMA50  \
# 986  152052500  163.759995  153.358335  161.641432  69.869847  151.958465
#
#          MACD  Bollinger_High  Bollinger_Low  Stochastic_Oscillator  \
# 986  0.892873      166.621543      143.89446              75.766884
#
#      Williams_R         OBV
# 986  -24.233116  3827696100
