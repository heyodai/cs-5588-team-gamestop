# %%
import pandas as pd
import json

# %%
class MarketStock:
    def __init__(self, ticker, dataset_fp):
        self.ticker = ticker
        self.dataset_fp = dataset_fp

    def get_prices(self, date):
        """
        Fetch prices for a given date

        Parameters
        ----------
        date : str
            Date to fetch prices for

        Returns
        -------
        list
            List of prices for the given date
        """
        # Load and process the data
        df = pd.read_csv(f"{self.dataset_fp}/price/raw/{self.ticker}.csv")
        df["Date"] = pd.to_datetime(df["Date"])
        df = df[df["Date"] == date]

        # Map rows to JSON
        prices_json = []
        for _, rows in df.iterrows():
            prices_json.append(
                {
                    "open": rows["Open"],
                    "close": rows["Close"],
                    "high": rows["High"],
                    "low": rows["Low"],
                    "volume": rows["Volume"],
                }
            )

        return prices_json

    def get_news(self, date):
        """
        Fetch news for a given date

        Parameters
        ----------
        date : str
            Date to fetch news for

        Returns
        -------
        list
            List of news for the given date
        """
        # Load and process the data
        df = pd.read_csv(f"{self.dataset_fp}/news/raw/{self.ticker}.csv", sep="	")
        df["date"] = pd.to_datetime(df["date"])
        df = df[df["date"] == date]

        # Map rows to JSON
        news_json = []
        for _, rows in df.iterrows():
            news_json.append({"title": rows["title"], "summary": rows["summary"]})

        return news_json

# %%
path = "/Users/odai/repos/cs-5588-team-gamestop/datasets/CMIN-US"
date = "2018-01-02"

aapl = MarketStock("AAPL", path)
print(aapl.get_prices(date))
print(aapl.get_news(date))
# Out:
# [{'open': 42.540001, 'close': 43.064999, 'high': 43.075001, 'low': 42.314999, 'volume': 102223600}]
# [{'title': "Cramer reflects on how Trump's actions are fueling the 'b...", 'summary': 'Jim Cramer examined the notion that investors are &quot;bored&quot; with the market rally and explained how the president is driving stocks higher.'}, {'title': 'Tech Leads Market Advance To New Highs; These Top Growth Stocks Break Out', 'summary': 'The major market averages ended the first trading session of 2018 near their highs logging strong gains a great start following impressive 2017 performances ibd display video id 3058793 width 50 float left autostart true The tech heavy Nasdaq led the way with a 1 5'}, {'title': 'Tuesday Apple Rumors: Battery Replacement is Available for Old iPhones', 'summary': 'InvestorPlace Stock Market News Stock Advice amp Trading Tips Leading the Apple Inc NASDAQ AAPL news today is its battery replacement plan Today we ll look at that and other Apple Rumors for Tuesday Battery Replacement Apple is'}, {'title': 'Here&apos;s Why Optical Networking Stocks Fell in December', 'summary': 'Many optical networking stocks plunged last month, often for no obvious reason. Here&apos;s a deeper look at what was going on.'}, {'title': 'Why Apple Could Be a Big Buyer in 2018', 'summary': 'Jan.02 -- Jim Suva, senior tech analyst and managing director at Citigroup, discusses Apple and tech merger mania on &quot;Bloomberg Technology.&quot;'}, {'title': 'Apple Just Bought This Canadian Software Startup', 'summary': 'Will help Apple&apos;s software development efforts.'}, {'title': 'Apple buys developer tool-maker Buddybuild', 'summary': 'Apple Inc. has acquired Buddybuild, a Vancouver, Canada-based company that makes software development tools, according to a Buddybuild blog. Apple stock is down a fraction to $172.05 in late trading. Buddybuild, ...'}, {'title': 'Stocks Up Broadly, Apple Strong; Will This Bitcoin ETF Soar In 2018?', 'summary': 'U S stocks got off to a riveting start to the new year particularly in the tech sectors as Apple AAPL behaved the way one would expect for a leading stock that is testing support at a key technical juncture ibd display video id 3058957 width 50 float left autostart'}, {'title': 'The FANG+ Stocks Are All At Key Technical Levels', 'summary': 'The Nasdaq surged 28 in 2017 as big name tech stocks continued to show their dominance How well did the FANG stocks perform and could there be more room for them to run in 2018 Here s the scorecard for Facebook FB Amazon AMZN Netflix'}, {'title': '7 Tech Stocks Chase Coleman Is Buying Heading Into 2018', 'summary': 'InvestorPlace Stock Market News Stock Advice amp Trading Tips At 42 years old Chase Coleman is possibly the youngest of the big league hedge fund managers In 2011 when he was 36 his Tiger Global long short equity fund returned over 45 That made it the most profitable hedge fund'}, {'title': "Netflix Is 'Miles Ahead' Of Rivals, Analyst Says; Stock Soars", 'summary': 'Netflix NFLX shares jumped on Tuesday after the internet television network received a pair of bullish analyst reports to start the new year ibd display video id 3058944 width 50 float left autostart true 160 Loop Capital Markets analyst David Miller reiterated his'}, {'title': 'AMD, Netflix, Nvidia lead Silicon Valley stocks as Wall Street surges into New Year', 'summary': "Stocks got a healthy start in their first day of trading in 2018, with the Bloomberg Silicon Valley High Tech Index showing a 1.63 percent increase. Bloomberg's index — a roundup of 20 stocks of public ..."}, {'title': 'Review: Why The iPhone X Is The Worst iPhone Ever', 'summary': 'The iPhone X is a lot harder to use than the older generation of the iPhone because Apple failed to adapt its iOS 10 operating system to the new iPhone design which got rid of the physical Home button. A mistake that we think Apple will fix by reintroducing a Home button on the next generation.'}, {'title': 'Nasdaq Tops 7,000 to Score New Record; S&P 500 Also Closes at Record High', 'summary': "The Dow finished higher on Tuesda ...

# %%
class Market:
    def __init__(self, dataset_fp):
        stocks = ['AAPL', 'JNJ', 'CVX', 'BAC', 'WMT'] # TODO: Make this dynamic
        self.stocks = {}
        for stock in stocks:
            self.stocks[stock] = MarketStock(stock, dataset_fp)
            
    def get_info(self, date):
        """
        Fetch information for all stocks for a given date
        
        Parameters
        ----------
        date : str
            Date to fetch information for
            
        Returns
        -------
        dict
            Dictionary containing information for the given date
        """
        stock_info = {}
        for ticker, stock in self.stocks.items():
            stock_info[ticker] = {
                "prices": stock.get_prices(date),
                "news": stock.get_news(date)
            }
        
        return stock_info

# %%
date = "2018-01-02"
path = "/Users/odai/repos/cs-5588-team-gamestop/datasets/CMIN-US"

market = Market(path)
print(json.dumps(market.get_info(date), indent=4))
# Out:
# {
#     "AAPL": {
#         "prices": [
#             {
#                 "open": 42.540001,
#                 "close": 43.064999,
#                 "high": 43.075001,
#                 "low": 42.314999,
#                 "volume": 102223600
#             }
#         ],
#         "news": [
#             {
#                 "title": "Cramer reflects on how Trump's actions are fueling the 'b...",
#                 "summary": "Jim Cramer examined the notion that investors are &quot;bored&quot; with the market rally and explained how the president is driving stocks higher."
#             },
#             {
#                 "title": "Tech Leads Market Advance To New Highs; These Top Growth Stocks Break Out",
#                 "summary": "The major market averages ended the first trading session of 2018 near their highs logging strong gains a great start following impressive 2017 performances ibd display video id 3058793 width 50 float left autostart true The tech heavy Nasdaq led the way with a 1 5"
#             },
#             {
#                 "title": "Tuesday Apple Rumors: Battery Replacement is Available for Old iPhones",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips Leading the Apple Inc NASDAQ AAPL news today is its battery replacement plan Today we ll look at that and other Apple Rumors for Tuesday Battery Replacement Apple is"
#             },
#             {
#                 "title": "Here&apos;s Why Optical Networking Stocks Fell in December",
#                 "summary": "Many optical networking stocks plunged last month, often for no obvious reason. Here&apos;s a deeper look at what was going on."
#             },
#             {
#                 "title": "Why Apple Could Be a Big Buyer in 2018",
#                 "summary": "Jan.02 -- Jim Suva, senior tech analyst and managing director at Citigroup, discusses Apple and tech merger mania on &quot;Bloomberg Technology.&quot;"
#             },
#             {
#                 "title": "Apple Just Bought This Canadian Software Startup",
#                 "summary": "Will help Apple&apos;s software development efforts."
#             },
#             {
#                 "title": "Apple buys developer tool-maker Buddybuild",
#                 "summary": "Apple Inc. has acquired Buddybuild, a Vancouver, Canada-based company that makes software development tools, according to a Buddybuild blog. Apple stock is down a fraction to $172.05 in late trading. Buddybuild, ..."
#             },
#             {
#                 "title": "Stocks Up Broadly, Apple Strong; Will This Bitcoin ETF Soar In 2018?",
#                 "summary": "U S stocks got off to a riveting start to the new year particularly in the tech sectors as Apple AAPL behaved the way one would expect for a leading stock that is testing support at a key technical juncture ibd display video id 3058957 width 50 float left autostart"
#             },
#             {
#                 "title": "The FANG+ Stocks Are All At Key Technical Levels",
#                 "summary": "The Nasdaq surged 28 in 2017 as big name tech stocks continued to show their dominance How well did the FANG stocks perform and could there be more room for them to run in 2018 Here s the scorecard for Facebook FB Amazon AMZN Netflix"
#             },
#             {
#                 "title": "7 Tech Stocks Chase Coleman Is Buying Heading Into 2018",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips At 42 years old Chase Coleman is possibly the youngest of the big league hedge fund managers In 2011 when he was 36 his Tiger Global long short equity fund returned over 45 That made it the most profitable hedge fund"
#             },
#             {
#                 "title": "Netflix Is 'Miles Ahead' Of Rivals, Analyst Says; Stock Soars",
#                 "summary": "Netflix NFLX shares jumped on Tuesday after the internet television network received a pair of bullish analyst reports to start the new year ibd display video id 3058944 width 50 float left autostart true 160 Loop Capital Markets analyst David Miller reiterated his"
#             },
#             {
#                 "title": "AMD, Netflix, Nvidia lead Silicon Valley stocks as Wall Street surges into New Year",
#                 "summary": "Stocks got a healthy start in their first day of trading in 2018, with the Bloomberg Silicon Valley High Tech Index showing a 1.63 percent increase. Bloomberg's index \u2014 a roundup of 20 stocks of public ..."
#             },
#             {
#                 "title": "Review: Why The iPhone X Is The Worst iPhone Ever",
#                 "summary": "The iPhone X is a lot harder to use than the older generation of the iPhone because Apple failed to adapt its iOS 10 operating system to the new iPhone design which got rid of the physical Home button. A mistake that we think Apple will fix by reintroducing a Home button on the next generation."
#             },
#             {
#                 "title": "Nasdaq Tops 7,000 to Score New Record; S&P 500 Also Closes at Record High",
#                 "summary": "The Dow finished higher on Tuesday as well, but didn't hit a new record."
#             },
#             {
#                 "title": "Apple Inc.'s 6.46-Inch iPhone X Could Be a Huge Seller",
#                 "summary": "In 2017 Apple NASDAQ AAPL disappointed some iPhone enthusiasts by releasing its hotly anticipated iPhone X in a single screen size 5 85 inches along the diagonal For many potential iPhone users such a large screen in a device that s not that much larger than the"
#             },
#             {
#                 "title": "Will Trump and the Post Office Ruin the Run for Amazon.com, Inc.?",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips On Friday Amazon com Inc NASDAQ AMZN shares sank 1 4 thanks to a tweet rampage by President Donald Trump More specifically Trump went on Twitter Inc NYSE TWTR and made the case that the United"
#             },
#             {
#                 "title": "The FANG+ Stocks Are All At Key Technical Levels",
#                 "summary": "How well did FANG+ stocks Facebook, Amazon, Netflix, Google and Apple perform in 2017, and could there be more be more room for them to run in 2018?"
#             },
#             {
#                 "title": "Why Netflix, Inc. Stock is Surging Today",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips Netflix Inc NASDAQ NFLX stock was up on Tuesday following an upgrade from an analyst Source Vivian D Nguyen via Flickr Modified The upgrade to NFLX stock comes from 160 Macquarie Research analyst 160"
#             },
#             {
#                 "title": "Could Apple Become A $1 Trillion Market Cap Stock In 2018?",
#                 "summary": "Apple got some bullish analyst reports, with one claiming it&apos;s on path to reach a market value of $1 trillion this year."
#             },
#             {
#                 "title": "Here are 3 investible events that could happen in 2018: A...",
#                 "summary": "Paul Sagawa, Sector and Sovereign Research, highlights three things investors should watch in 2018."
#             },
#             {
#                 "title": "Apple Acquires Buddybuild",
#                 "summary": "Apple Acquires Buddybuild"
#             },
#             {
#                 "title": "Stocks Up Broadly, Apple Strong; Will This Bitcoin ETF Soar In 2018?",
#                 "summary": "Commodity, tech and medical stocks rallied nicely on the first day of trading. A top Bitcoin ETF soared."
#             },
#             {
#                 "title": "We see Apple doing more 'add-on' acquisitions: Gerber Kaw...",
#                 "summary": "Ross Gerber, Gerber Kawasaki, and Ed Lee, Recode, discuss some analysts' merger predictions for 2018."
#             },
#             {
#                 "title": "Here's Why Apple Is Drexel's Top IT Pick For 2018",
#                 "summary": "Drexel Hamilton has named\u00a0 Apple Inc. (NASDAQ: AAPL ) as its top pick in the IT hardware and software sector in 2018. The Analyst Drexel Hamilton analyst Brian White has a Buy rating on Apple with a $235 ..."
#             },
#             {
#                 "title": "Here's Why Netflix (NFLX) Stock Is Climbing Today",
#                 "summary": "Shares of Netflix NFLX were up more than 4 5 in morning trading Tuesday as analysts praised the video streaming company s original content strategy and reignited rumors that the brand could be a candidate for a takeover by Apple AAPL Netflix is miles ahead in terms of programming"
#             },
#             {
#                 "title": "Huawei Guns for Apple Inc. and Samsung in 2018 With Planned U.S. Push",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips Apple Inc s NASDAQ AAPL iPhone X Alphabet Inc s NASDAQ GOOGL Google Pixel 2 and the Galaxy S8 were the smartphone releases that got the spotlight in 2017 But"
#             },
#             {
#                 "title": "Avie Tevanian: More on Blockchain, A.I., IoT",
#                 "summary": "This week\u2019s Barron\u2019s print magazine features an interview I did with Avadis\u00a0\u201cAvie\u201d Tevanian, formerly head of software at Apple (AAPL), and now an experienced venture capitalist with VC fund NextEquity Partners, with investments in Uber and The RealReal.  Boy, that is a great question."
#             },
#             {
#                 "title": "Apple Inc.&apos;s 6.46-Inch iPhone X Could Be a Huge Seller",
#                 "summary": "Don&apos;t underestimate the potential demand for Apple&apos;s upcoming large-screen OLED iPhone."
#             },
#             {
#                 "title": "On topic: Tech news to know now",
#                 "summary": "Here\u2019s what\u2019s going on in tech. Apple will replace batteries in iPhone 6 or later models for $29 even if the phone passes a diagnostic test. (MacRumors) ICYMI in the "
#             },
#             {
#                 "title": "Tuesday Apple Rumors: Battery Replacement is Available for Old iPhones",
#                 "summary": "Leading the Apple Inc. (NASDAQ:AAPL) news today is its battery replacement plan. Today, we&#8217;ll look at that and other Apple Rumors for Tuesday."
#             },
#             {
#                 "title": "Will The iPhone Performance Throttling Controversy Impact Apple?",
#                 "summary": "Over the last two weeks, Apple admitted that it was throttling of performance of iPhones as their batteries age while also issuing an apology to customers. The move comes after the company faced criticism over a slowdown in the performance of older iPhones with recent software updates"
#             },
#             {
#                 "title": "Citigroup: There\u2019s a 40% chance Apple buys Netflix",
#                 "summary": "Cupertino-based Apple is interested in making a major acquisition of a car company, video game company or entertainment company, with Netflix being their most likely target, Citigroup analysts said in a recent note to investors.  Citi analysts Jim Suva and Asiya Merchant believe there\u2019s a 40 percent chance Apple buys Netflix, a 25 percent chance the company buys The Walt Disney Co., a 10 percent chance the company buys video game makers Activision Blizzard, Electronic Arts or Take-Two Interactive Software, and a 5 percent chance the company buys Tesla, Business Insider reports ."
#             },
#             {
#                 "title": "Apple, Nvidia Fuel Tech Stocks; Is Bitcoin Last Year&apos;s News?",
#                 "summary": "Wall Street kicked off the new year as Apple and Nvidia led tech stocks higher. Emerging markets surged, while Bitcoin climbed."
#             },
#             {
#                 "title": "Here&apos;s Why Netflix (NFLX) Stock Is Climbing Today",
#                 "summary": "Shares of Netflix (NFLX) were up more than 4.5% in morning trading Tuesday as analysts praised the video streaming company&apos;s original content strategy and reignited rumors that the brand could be a candidate for a takeover by Apple (AAPL)."
#             },
#             {
#                 "title": "Stocks Charge Ahead; Will Apple Buy Netflix?",
#                 "summary": "Stocks indexes opened the new year s first session on a cheerful note as the major indexes gripped solid gains midday Tuesday ibd display video id 3058793 width 50 float left autostart true The Nasdaq popped 1 1 while the S amp P 500 and the Dow Jones industrial average"
#             },
#             {
#                 "title": "The FANG+ Stocks Are All At Key Technical Levels To Start 2018",
#                 "summary": "The Nasdaq surged 28 in 2017 as big name tech stocks continued to show their dominance How well did the FANG stocks perform and could there be more room for them to run in 2018 Here s the scorecard for Facebook FB Amazon AMZN Netflix"
#             },
#             {
#                 "title": "7 Tech Stocks Chase Coleman Is Buying Heading Into 2018",
#                 "summary": "At 42 years old, Chase Coleman is possibly the youngest of the big-league hedge fund managers. In 2011, when he was 36, his Tiger Global long/short equity fund returned over 45%. That made it the most profitable hedge fund in the world according to Bloomberg. His other claim to fame is that he was an early investor in Facebook, an investment that no doubt contributed to his $2.2 billion net worth. Source: Shutterstock"
#             },
#             {
#                 "title": "Here are three reasons why you should change your old iPh...",
#                 "summary": "Apple is now replacing batteries on iPhone 6 smartphones or later models for $29."
#             },
#             {
#                 "title": "Why Netflix, Inc. Stock is Surging Today",
#                 "summary": "The upgrade to NFLX stock comes from\u00a0Macquarie Research analyst\u00a0Tim Nollen.  Nollen\u2019s positive outlook on Netflix, Inc. resulted in him increasing the firm\u2019s rating for NFLX stock from \u201cNeutral\u201d to \u201cOutperform.\u201d He also increased his price target for the stock from $200 to $220.  Netflix was trading at $191.96 per share when the markets closed on Friday."
#             },
#             {
#                 "title": "MKM Partners: Who's competing in big tech's race to a tri...",
#                 "summary": "MKM Partners' Rob Sanderson discusses the growing competition between Apple and Amazon as well as other large companies to see which will be the first to reach a $1 trillion valuation."
#             },
#             {
#                 "title": "Will Trump and the Post Office Ruin the Run for Amazon.com, Inc.?",
#                 "summary": "On Friday, Amazon.com, Inc. (NASDAQ:AMZN) shares sank 1.4% thanks to a tweet rampage by President Donald Trump.  More specifically, Trump went on Twitter Inc (NYSE:TWTR) and made the case that the United States Post Office, \u201cwhich is losing many billions of dollars a year,\u201d doesn\u2019t charge Amazon enough.  According to the president, USPS \u201cshould be charging MUCH MORE!\u201d Of course, founder and CEO Jeff Bezos also owns the Washington Post, an outlet that Trump has criticized in the past as well."
#             },
#             {
#                 "title": "CNBC Tech Check Morning Edition: January 02, 2018",
#                 "summary": "CNBC\u2019s Tech Check brings you the latest in tech news from CNBC\u2019s 1 Market in the heart of San Francisco."
#             },
#             {
#                 "title": "Apple's becoming a nicer company: Unikrn CEO on 'battery-...",
#                 "summary": "Rahul Sood, Unikrn CEO, and Ed Lee, Recode managing editor, discusses Apple's battery replacement offer in response to the news they deliberately slowed older phones to keep up acceptable performance."
#             },
#             {
#                 "title": "iPhone X Availability to Reach Balance With Demand Mid-January",
#                 "summary": "Apple's supply of iPhone X should reach balance with demand for the new phone by the middle of this month. And reports of iPhone production cuts are probably incorrect according to one analyst."
#             },
#             {
#                 "title": "How to Find Out if Your iPhone Is Eligible for Apple\u2019s $29 Battery Replacement",
#                 "summary": "Apple has clarified which iPhones qualify and in what circumstances."
#             },
#             {
#                 "title": "Olson Expects Expanded Array of iPhone X Styles",
#                 "summary": "Jan.02 -- Michael Olson, senior research analyst at Piper Jaffray, discusses the outlook for Apple and the company's problems with batteries. He speaks with Jonathan Ferro on &quot;Bloomberg Markets: The Open.&quot;"
#             },
#             {
#                 "title": "Cramer: Apple's iPhone 'batterygate' issue doesn't matter and investors shouldn't sell",
#                 "summary": "Jim Cramer believes Apple's iPhone battery problems don't really matter and investors shouldn't sell the stock."
#             },
#             {
#                 "title": "Huawei Guns for Apple Inc. and Samsung in 2018 With Planned U.S. Push",
#                 "summary": "Apple Inc.\u2019s (NASDAQ:AAPL) iPhone X, Alphabet Inc\u2019s (NASDAQ:GOOGL) Google Pixel 2 and the Galaxy S8 were the smartphone releases that got the spotlight in 2017.  A report that the Huawei Mate 10 may be getting a U.S. carrier launch \u2014 complete with a big, $100 million marketing push \u2014 should have the established smartphone leaders worried."
#             },
#             {
#                 "title": "Is Microsoft Corporation a Buy?",
#                 "summary": "The company has successfully revamped its business."
#             },
#             {
#                 "title": "Analyst expectations for the iPhone X are still split",
#                 "summary": "The analyst told clients that any first-quarter 2018 volume estimate over 35 million &quot;will prove too high.&quot;"
#             },
#             {
#                 "title": "'Pok\u00e9mon GO' Will Finally Invade China In 2018 As The Game Starts A 'Journey To Mars'",
#                 "summary": "Pok\u00e9mon GO is all about battling monsters, but the game might be about to slay its greatest foe of all, stringent Chinese regulation."
#             },
#             {
#                 "title": "Stocks Rally on First Trading Day of 2018 as U.S. Dollar Declines",
#                 "summary": "Stocks trade higher on Tuesday, the first trading day of 2018."
#             },
#             {
#                 "title": "Why Prince Harry Should Nix Obama Royal Wedding Invite",
#                 "summary": "Former president Obama has shown himself to be no friend of the British people."
#             },
#             {
#                 "title": "Company News For January 2, 2018",
#                 "summary": "Companies in The News are: GS,AAPL,NFLX,IBM,PCLN"
#             },
#             {
#                 "title": "Apple Inc\u2019s Best Years Are Behind It \u2014 Prepare for AAPL Stock\u2019s Decline",
#                 "summary": "Was 2017 the last great year for Apple Inc. (NASDAQ:AAPL)?  Paul Mampilly, my colleague over at Banyan Hill, has a very dire prediction for AAPL stock.  \u201c\u201cApple is doomed,\u201d he says, \u201c\u2026 most people buying Apple stock are buying into a memory."
#             },
#             {
#                 "title": "Apple Inc.&apos;s iPhone Market Share Problem",
#                 "summary": "Apple&apos;s challenge in the years ahead will be to grow its share of the high-end smartphone market."
#             },
#             {
#                 "title": "Stocks to Watch: Apple, Netflix, Disney, J&J, McDonald's, Weight Watchers",
#                 "summary": "Among the companies with shares expected to trade actively in Tuesday's session are Apple Inc., Netflix Inc., Walt Disney Co., Johnson & Johnson and McDonald's Corp."
#             },
#             {
#                 "title": "Is Apple Buying Netflix? Here's Why You Can Ignore Some Analyst Predictions",
#                 "summary": "Citi analysts say there's a 40% chance that Apple will buy Netflix. Find out why they might be motivated to make that call and why it's not likely to happen."
#             },
#             {
#                 "title": "Sell Apple on battery life canard? No!: Jim Cramer",
#                 "summary": "The &quot;Squawk on the Street&quot; crew discusses Apple's $29 battery replacement offer for iPhone 6 and later devices."
#             },
#             {
#                 "title": "Tech Today: Energous Zooms Again, Netflix Gains, Checking into Apple iPhone Supply",
#                 "summary": "Here are some\u00a0things going on today in your world of tech: Nasdaq Futures are up about 0.4%, at $6,432.25, and bellwether tech names are on the march higher, with Apple\u00a0(AAPL) up $1.01, or half a percent, at $170.24, and Intel (INTC), Cisco Systems (CSCO), Microsoft (MSFT), and IBM (IBM) all higher by about half a percent.  The net price gain leaders among are Netflix\u00a0(NFLX), which is up $3.74, or 2%, at $195.70, after that stock was upgraded by\u00a0Macquarie's\u00a0Tim Nollen to Outperform from Hold, predicting further defections from ad-supported TV to subscription services.  What better way to start the new year than with a discussion of Apple\u2019s iPhone\u00a0situation."
#             },
#             {
#                 "title": "The Top Ten Technology Books Of 2017",
#                 "summary": "Here is Forbes Technovation columnist Peter High's take at the top ten technology books of 2017."
#             },
#             {
#                 "title": "Apple iPhone X expectations are 'still too high' despite stock pullback, analyst says",
#                 "summary": "Apple iPhone X volume expectations are still too high despite a recent correction in investor expectations, according CLSA."
#             },
#             {
#                 "title": "You should replace your iPhone 6 battery",
#                 "summary": "Apple is now offering $29 replacement batteries for the iPhone 6 and newer models after it was criticized for slowing down older iPhones."
#             },
#             {
#                 "title": "Apple shares rise premarket after Piper Jaffray says they are in a 'super-long cycle'",
#                 "summary": "A survey of 400 iPhone buyers has bolstered Piper Jaffray analysts' expectations for the mix of iPhones to be sold in fiscal 2018, according to a note published Tuesday. \"Specifically, we are modeling ..."
#             },
#             {
#                 "title": "Apple shares rise premarket after Piper Jaffray says they are in a 'super-long cycle'",
#                 "summary": "A survey of 400 iPhone buyers has bolstered Piper Jaffray analysts' expectations for the mix of iPhones to be sold in fiscal 2018, according to a note published Tuesday. \"Specifically, we are modeling ..."
#             },
#             {
#                 "title": "Tuesday\u2019s Vital Data: Micron Technology, Inc. (MU), General Electric Company (GE) and Amazon.com, Inc. (AMZN)",
#                 "summary": "U.S. stock futures are mixed heading into the first trading day of 2018.  Geopolitical concerns are headlining this morning, with North Korean leader Kim Jong Un claiming to have a \u201cnuclear button.\u201d However, Un suggested he is willing to engage in talks with South Korea at next month\u2019s Winter Olympics.  Overall, about 13.8 million calls and 11.8 million puts changed hands."
#             },
#             {
#                 "title": "BP, Apple and the Dollar - 5 Things You Must Know Before the Market Opens",
#                 "summary": "U.S. stock futures are indicating that Wall Street will continue its record run on the first trading day of 2018 as the dollar slumps."
#             },
#             {
#                 "title": "The World\u2019s Biggest Gadget Show Matters Again",
#                 "summary": "Thank new hardware categories for bringing CES back to life."
#             },
#             {
#                 "title": "Global Smartphone Production to Fall This Year",
#                 "summary": "A widely regarded research firm forecasts that global smartphone production will fall 5% this year. The drop will be uneven as several companies face severe challenges."
#             },
#             {
#                 "title": "Citi Sets Odds For Apple-Netflix Merger",
#                 "summary": "Citi Sets Odds For Apple-Netflix Merger"
#             },
#             {
#                 "title": "Citi: 40% Chance of Apple Acquiring Netflix",
#                 "summary": "Recent tax reforms mean that Apple is now sitting on enough cash to comfortably finance a big acqusiiton, according to Citi."
#             },
#             {
#                 "title": "Apple iOS 11.2.5 Release: It's A Big One",
#                 "summary": "Apple's release of iOS 11.2.5 is a huge deal..."
#             }
#         ]
#     },
#     "JNJ": {
#         "prices": [
#             {
#                 "open": 139.660004,
#                 "close": 139.229996,
#                 "high": 139.949997,
#                 "low": 138.720001,
#                 "volume": 6842100
#             }
#         ],
#         "news": [
#             {
#                 "title": "Daily Dividend Report: JNJ, WSO, LTC, CMRE",
#                 "summary": "Johnson amp Johnson JNJ has declared a cash dividend for the first quarter of 2018 of 0 84 per share on the company s common stock The dividend is payable on March 13 2018 to shareholders of record at the close of business on February 27 2018 The ex dividend date is February 26"
#             },
#             {
#                 "title": "FDA issues recall on J&J heart device",
#                 "summary": "The U.S. Food and Drug Administration on  Tuesday issued a recall of a heart device made by a unit of  Johnson & Johnson due to a faulty valve.  About 110 Agilis Steerable Introducer Sheath devices made  and distributed between Jan. 1 and May 5 are a part of the Class  I recall, according to the FDA.  Johnson & Johnson did not immediately respond to a request  for comment."
#             },
#             {
#                 "title": "How Intuitive Surgical Can Be A $450 Stock?",
#                 "summary": "Intuitive Surgical s 160 JNJ stock saw strong gains in 2017 increasing by more than 70 The investor optimism was fueled by the growth in the number of procedures and recurring revenue streams The obvious question that arises is can the stock go up even further We believe that"
#             },
#             {
#                 "title": "The Zacks Analyst Blog Highlights: Johnson and Johnson, AbbVie, Roche's, AstraZeneca and Novo-Nordisk A/S",
#                 "summary": "For Immediate Release Chicago IL Jan 02 2018 Zacks com announces the list of stocks featured in the Analyst Blog Every day the Zacks Equity Research analysts discuss the latest news and events impacting stocks and the financial markets Stocks recently featured in the blog include"
#             },
#             {
#                 "title": "3 Best Big Pharma Stocks to Buy for 2018",
#                 "summary": "If you re expecting massive revenue growth for 2018 among big pharma stocks think again Despite hot new drugs for several major drugmakers many of them also will likely be held back by declining sales for older drugs Wall Street only expects low single digit percentage revenue"
#             },
#             {
#                 "title": "Should You Dump Johnson & Johnson for Baxter and Abbott?",
#                 "summary": "While Johnson & Johnson is far from a bad company, there may be more upside in Abbott Laboratories and Baxter International."
#             },
#             {
#                 "title": "Stocks to Watch: Apple, Netflix, Disney, J&J, McDonald's, Weight Watchers",
#                 "summary": "Among the companies with shares expected to trade actively in Tuesday's session are Apple Inc., Netflix Inc., Walt Disney Co., Johnson & Johnson and McDonald's Corp."
#             },
#             {
#                 "title": "3 Best Big Pharma Stocks to Buy for 2018",
#                 "summary": "These big pharma stocks stand out head and shoulders above the rest."
#             },
#             {
#                 "title": "The Zacks Analyst Blog Highlights: Johnson and Johnson, AbbVie, Roche&apos;s, AstraZeneca and Novo-Nordisk A/S",
#                 "summary": "The Zacks Analyst Blog Highlights: Johnson and Johnson, AbbVie, Roche&apos;s, AstraZeneca and Novo-Nordisk A/S"
#             },
#             {
#                 "title": "Stocks making the biggest moves premarket: JNJ, LEN, ABT, BP, LVS, WYNN & more",
#                 "summary": "These are the stocks posting the largest moves before the bell."
#             },
#             {
#                 "title": "What Analysts Recommend for Johnson & Johnson in December 2017",
#                 "summary": "24 analysts were tracking Johnson & Johnson in December 2017. Five analysts recommended a \u201cstrong buy,\u201d while eight analysts recommended a \u201cbuy.\u201d"
#             },
#             {
#                 "title": "Johnson & Johnson Announces Quarterly Dividend for First Quarter 2018",
#                 "summary": "NEW BRUNSWICK, N.J., Jan. 2, 2018 /PRNewswire/ --\u00a0Johnson & Johnson (JNJ) today announced that its Board of Directors has declared a cash dividend for the first quarter of 2018 of $0.84 per share on the company's common stock.\u00a0The dividend is payable on March 13, 2018 to shareholders of record at the close of business on February 27, 2018.  Caring for the world, one person at a time\u2026inspires and unites the people of Johnson & Johnson."
#             }
#         ]
#     },
#     "CVX": {
#         "prices": [
#             {
#                 "open": 125.709999,
#                 "close": 127.580002,
#                 "high": 127.739998,
#                 "low": 125.540001,
#                 "volume": 5626000
#             }
#         ],
#         "news": [
#             {
#                 "title": "Chevron\u2019s 50-Day Moving Average Rises Steeply: What Does It Mean?",
#                 "summary": "Chevron (CVX) stock started the year on a downtrend. Chevron\u2019s 50-day moving average fell but stayed above its 200-day moving average."
#             },
#             {
#                 "title": "Stocks Up Broadly, Apple Strong; Will This Bitcoin ETF Soar In 2018?",
#                 "summary": "U S stocks got off to a riveting start to the new year particularly in the tech sectors as Apple AAPL behaved the way one would expect for a leading stock that is testing support at a key technical juncture ibd display video id 3058957 width 50 float left autostart"
#             },
#             {
#                 "title": "Notable Tuesday Option Activity: CVX, TWTR, CALM",
#                 "summary": "Looking at options trading activity among components of the Russell 3000 index there is noteworthy activity today in Chevron Corporation Symbol CVX where a total volume of 29 894 contracts has been traded thus far today a contract volume which is representative of approximately 3 0"
#             },
#             {
#                 "title": "Close Update: Wall Street Starts Year With Gains as Energy, Tech Shares Rally",
#                 "summary": "Stocks started the new year on a firm footing Tuesday with strong gains in Walt Disney DIS lifting the Dow Jones Industrial Average while the Nasdaq Composite outperformed the benchmarks amid advances in biotech and information technology names Stocks started the new year on a firm"
#             },
#             {
#                 "title": "Wall Street Starts Year With Gains as Energy, Tech Shares Rally",
#                 "summary": "Stocks started the new year on a firm footing Tuesday with strong gains in Walt Disney DIS lifting the Dow Jones Industrial Average while the Nasdaq Composite outperformed the benchmarks amid gains in biotech and information technology names Stocks started the new year on a firm"
#             },
#             {
#                 "title": "Chevron Stock at a 52-Week High in 4Q17",
#                 "summary": "Chevron (CVX) stock has risen 6.4% since October 2, 2017, outperforming the SPDR S&P 500 ETF (SPY), which has risen 6.0% in the same period."
#             },
#             {
#                 "title": "Chevron Should Beat Exxon as Your Favorite Big Oil Stock in 2018",
#                 "summary": "Chevron is a standout among the rest of the energy sector right now. And it's sending a clear buy signal as we head into January."
#             },
#             {
#                 "title": "BP sets $1.5 billion charge for U.S tax changes but sees long-term boost",
#                 "summary": "Oil giant BP (BP.L) will take a one-off $1.5 billion (1 billion pounds) charge to adjust to new U.S. tax rules, but expects a long-term boost from the corporate-friendly tax rates, it said on Tuesday.  BP's rival Royal Dutch Shell (RDSa.L) said last week it would incur a one-off charge of $2-$2.5 billion for the U.S. tax changes.  Like BP, Shell and many other international companies said they expected a long-term positive impact to U.S. earnings from the massive $1.5 trillion tax overhaul that U.S. President Donald Trump signed into law last month."
#             },
#             {
#                 "title": "BP sets $1.5 bln charge for U.S tax changes but sees long-term boost",
#                 "summary": "Oil giant BP will take a  one-off $1.5 billion charge to adjust to new U.S. tax rules, but  expects a long-term boost from the corporate-friendly tax rates,  it said on Tuesday.  BP's rival Royal Dutch Shell said last week it  would incur a one-off charge of $2-$2.5 billion for the U.S. tax  changes.  Like BP, Shell and many other international companies said  they expected a long-term positive impact to U.S. earnings from  the massive $1.5 trillion tax overhaul that U.S. President  Donald Trump signed into law last month."
#             },
#             {
#                 "title": "How Will BP's Shareholders Benefit From The New Tax Bill?",
#                 "summary": "The year 2017 has ended on a good note for the US corporate sector with the passing of the new tax act in the country The new law not only entails the reduction of corporate tax from 35 to 21 it also includes a number of other provisions that will particularly favor the oil and gas industry"
#             }
#         ]
#     },
#     "BAC": {
#         "prices": [
#             {
#                 "open": 29.75,
#                 "close": 29.9,
#                 "high": 29.9,
#                 "low": 29.610001,
#                 "volume": 57121600
#             }
#         ],
#         "news": [
#             {
#                 "title": "Bitcoin Jumps On Report Peter Thiel Fund Is Big Holder; Russia Eyes 'Cryptoruble'",
#                 "summary": "Bitcoin is rebounding Tuesday after starting the new year with a loss buoyed in part on a report that a Peter Thiel venture capital fund has a big Bitcoin holding Meanwhil Ripple and Ethereum jumped as Russia is reportedly looking creating its own cryptoruble ibd display"
#             },
#             {
#                 "title": "After Hours Most Active for Jan 2, 2018 :  SFUN, LC, SGMS, HII, CHD, JD, INTC, BAC, QQQ, LX, PFE, MSFT",
#                 "summary": "The NASDAQ 100 After Hours Indicator is up 2 48 to 6 513 82 The total After hours volume is currently 47 783 091 shares traded The following are the most active stocks for the after hours session Fang Holdings Limited SFUN is unchanged at 5 33 with 7 226 569"
#             },
#             {
#                 "title": "Bank of America's Shares Saw A Strong Performance In 2017, Even As Banking Sector Underperforms",
#                 "summary": "Notably, the rally in the U.S. stock market saw the S&P 500 post gains in each of the twelve months of 2017 for the first time in more than fifteen years."
#             },
#             {
#                 "title": "Stock Market News for January 02, 2018",
#                 "summary": "Benchmarks closed in the red on the final trading session of 2017 following a broad based sell off Additionally reports of Russian tankers supplying fuel to North Korea over the last few months raised geopolitical concerns which in turn weighed on markets Additionally all three key U"
#             },
#             {
#                 "title": "The Best 2018 New Year's Resolution You Can Make",
#                 "summary": "There s no better time than the beginning of the year to make important changes to your finances You can find plenty of ambitious ways to make your money life a little more comfortable Yet when it comes right down to it there s one single resolution that you can make to"
#             },
#             {
#                 "title": "Blanch Sees Oil in a Range Bound Market",
#                 "summary": "Jan.02 -- Francisco Blanch, global head of commodities research at Bank of America Merrill Lynch, discusses the outlook for oil and possible actions from OPEC. He speaks on &quot;Bloomberg Markets.&quot;"
#             },
#             {
#                 "title": "Banco Bradesco Sa (BBDO) Ex-Dividend Date Scheduled for January 03, 2018",
#                 "summary": "Banco Bradesco Sa BBDO will begin trading ex dividend on January 03 2018 A cash dividend payment of 0 004 per share is scheduled to be paid on February 12 2018 Shareholders who purchased BBDO prior to the ex dividend date are eligible for the cash dividend payment This represents"
#             },
#             {
#                 "title": "United Security Bancshares (UBFO) Ex-Dividend Date Scheduled for January 03, 2018",
#                 "summary": "United Security Bancshares UBFO will begin trading ex dividend on January 03 2018 A cash dividend payment of 0 07 per share is scheduled to be paid on January 16 2018 Shareholders who purchased UBFO prior to the ex dividend date are eligible for the cash dividend payment United"
#             },
#             {
#                 "title": "Banco Bradesco Sa (BBD) Ex-Dividend Date Scheduled for January 03, 2018",
#                 "summary": "Banco Bradesco Sa BBD will begin trading ex dividend on January 03 2018 A cash dividend payment of 0 005 per share is scheduled to be paid on February 12 2018 Shareholders who purchased BBD prior to the ex dividend date are eligible for the cash dividend payment This represents an 97"
#             },
#             {
#                 "title": "Pre-Market Most Active for Jan 2, 2018 :  EGN, BAC, QQQ, TVIX, BABA, NOK, GE, AZN, SIGM, AAPL, SQQQ, XNET",
#                 "summary": "The NASDAQ 100 Pre Market Indicator is up 17 04 to 6 413 46 The total Pre Market volume is currently 2 251 945 shares traded The following are the most active stocks for the pre market session Energen Corporation EGN is unchanged at 57 57 with 1 456 048 shares"
#             },
#             {
#                 "title": "Financial Sector Update for 01/02/2018: JPM, BAC, WFC, C, USB, DB, ZION, TCF",
#                 "summary": "Top Financial Shares Top Financial Shares JPM 0 6 JPM 0 6 BAC 0 5 BAC 0 5 WFC flatWFC flat C 0 7 C 0 7 USB flatUSB flat Financial shares were mildly positive ahead of the first day of trading for 2018 On the economic calendar is the US manufacturing PMI at 9 45 am ET"
#             },
#             {
#                 "title": "Tuesday\u2019s Vital Data: Micron Technology, Inc. (MU), General Electric Company (GE) and Amazon.com, Inc. (AMZN)",
#                 "summary": "U.S. stock futures are mixed heading into the first trading day of 2018.  Geopolitical concerns are headlining this morning, with North Korean leader Kim Jong Un claiming to have a \u201cnuclear button.\u201d However, Un suggested he is willing to engage in talks with South Korea at next month\u2019s Winter Olympics.  Overall, about 13.8 million calls and 11.8 million puts changed hands."
#             }
#         ]
#     },
#     "WMT": {
#         "prices": [
#             {
#                 "open": 99.300003,
#                 "close": 98.589996,
#                 "high": 99.790001,
#                 "low": 98.519997,
#                 "volume": 10150500
#             }
#         ],
#         "news": [
#             {
#                 "title": "Kroger&apos;s ClickList Is a Winner, But the Stock Is a Mixed Bag",
#                 "summary": "The grocery chain&apos;s online service is driving sales, but margins could come under pressure."
#             },
#             {
#                 "title": "&quot;Fast Money&quot; final trades: WMT, VRX and more",
#                 "summary": "The \u201cFast Money\u201d traders share their final trades for the day including Cemex SAB de CV, Walmart, Valeant Pharmaceuticals and Kroger."
#             },
#             {
#                 "title": "Amazon.com to Buy Target Corporation? Actually, it Makes Some Sense.",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips It remains to be seen if the eye opening prediction that Amazon com Inc NASDAQ AMZN will acquire Target Corporation NYSE TGT this year was just a savvy publicity stunt or an actual expectation With"
#             },
#             {
#                 "title": "Noteworthy Tuesday Option Activity: RH, WMT, BMY",
#                 "summary": "Looking at options trading activity among components of the Russell 3000 index there is noteworthy activity today in RH Symbol RH where a total volume of 4 616 contracts has been traded thus far today a contract volume which is representative of approximately 461 600 underlying"
#             },
#             {
#                 "title": "Tech Analyst Predicts Amazon Will Buy Target in 2018",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips Gene 160 Munster a tech analyst believes that Amazon com Inc NASDAQ AMZN will purchase Target Corporation NYSE TGT in 2018 Source Shutterstock Gene Munster the cofounder of 160 Loup Venture"
#             },
#             {
#                 "title": "Dean Foods: Don\"t Worry About Spilled Milk",
#                 "summary": "As America's largest milk producer, the stock has been down with poor results and low milk prices"
#             },
#             {
#                 "title": "Prices of land for warehouses are skyrocketing across the US",
#                 "summary": "Land fit for future fulfillment centers for the likes of Amazon and Walmart saw huge spikes in prices last year."
#             },
#             {
#                 "title": "How Will Costco's International Business Perform Going Forward?",
#                 "summary": "Costco s 160 COST organic performance has been keeping pace with the U S retail industry in large part due to its business model In fact Costco was able to attract comparable sales growth of 10 in the fiscal first quarter in the U S even after it raised membership fees on June 1"
#             },
#             {
#                 "title": "Why Amazon Might Have Its Eyes on Target",
#                 "summary": "Jan.02 -- Bloomberg's Spencer Soper reports on the rumor that Amazon.com Inc. may be interested in acquiring Target Corp. He speaks on &quot;Bloomberg Markets.&quot;"
#             },
#             {
#                 "title": "Tesla Inc Stock Looks Headed for a Bumpy Ride in 2018",
#                 "summary": "For Tesla Inc (NASDAQ:TSLA), 2018 is a critical year. Tesla stock had a strong, if choppy, 2017, gaining 46%. But those gains were minimized by a year-end pullback: TSLA stock closed the year down roughly 20% from September highs.5 Top Mutual Funds to Buy to Keep Taxes to a Minimum"
#             },
#             {
#                 "title": "Amazon.com to Buy Target Corporation? Actually, it Makes Some Sense.",
#                 "summary": "It remains to be seen if the eye-opening prediction that Amazon.com, Inc. (NASDAQ:AMZN) will acquire Target Corporation (NYSE:TGT) this year was just a savvy publicity stunt, or an actual expectation.  It was Loup Venture co-founder Gene Munster\u2019s, by the way (yes, the same Munster that used to handicap stocks for Piper Jaffray), that made the call.  While few could argue that Amazon isn\u2019t the king of e-commerce, moving into the brick-and-mortar world wasn\u2019t quite Jeff Bezos\u2019 milieu."
#             },
#             {
#                 "title": "Tech Analyst Predicts Amazon Will Buy Target in 2018",
#                 "summary": "Gene Munster, the cofounder of\u00a0Loup Venture and former\u00a0Piper Jaffray analyst, says that Target would make a good match with Amazon for a few reasons.  Gene\u00a0Munster also notes that the acquisition would offer Amazon Target\u2019s \u201cmanageable but comprehensive store count.\u201d The tech analysts believes that AMZN may pay as much as\u00a0$41 billion for TGT, which is a 15% premium to its current value."
#             },
#             {
#                 "title": "Skechers (SKX) Efforts Place the Stock Favorably for 2018",
#                 "summary": "A glimpse of Skechers U S A Inc s SKX share price movement reveals that it has surged roughly 52 4 in the past three months outperforming the industry s growth of 21 2 Certainly the company s sound fundamentals robust third quarter 2017 results and a sturdy outlook have played"
#             },
#             {
#                 "title": "Walmart CIO's Priorities: Productizing IT And Process Automation With AI",
#                 "summary": "Clay Johnson has worked at iconic companies from FedEx to Boeing to GE. For the past year as CIO and EVP of Global Business Services of Walmart, he has learned a complex business, enacted a dramatic cultural change, and is on the path to productize IT while fostering process automation with AI."
#             },
#             {
#                 "title": "Amazon To Buy Target? That's Loup Ventures' 'Boldest' Prediction For The Year",
#                 "summary": "When it comes to Amazon.com, Inc. (NASDAQ: AMZN )\u2019s acquisition prospects, Twitter Inc (NYSE: TWTR ) and RingCentral Inc (NYSE: RNG ) are so 2017. This year, Loup Ventures and managing partner Gene Munster ..."
#             },
#             {
#                 "title": "Jan Kniffen: More money in people's paychecks in February...",
#                 "summary": "Jan Kniffen, J. Rogers Kniffen Worldwide CEO, discusses what he sees for the retail sector in 2018 after a solid holiday season and the passage of tax reform."
#             },
#             {
#                 "title": "Top 17 Technology Articles Of 2017",
#                 "summary": "As 2017 passes, and we look forward to the year ahead, here is my fifth annual list of the ten best long-form stories about technology from the last year."
#             },
#             {
#                 "title": "Liberty Interactive Acquires HSN, Boosts Online Portfolio",
#                 "summary": "Liberty Interactive Corporation s QVCA QVC division recently completed the acquisition of the remaining 61 8 of the home shopping platform HSN Inc in an all stock deal worth 2 1 billion QVC owns 38 2 of HSN The deal was closed post shareholders approval on Dec 29 With this buyout"
#             },
#             {
#                 "title": "Walmart Stock is a \u2018Dividend Aristocrat\u2019 Worth Watching",
#                 "summary": "InvestorPlace Stock Market News Stock Advice amp Trading Tips Wal Mart Stores Inc NYSE WMT is a discount retail heavyweight that is also a dividend aristocrat The dividend aristocrats 160 are a select group of 51 companies in the S amp P 500"
#             },
#             {
#                 "title": "Skechers (SKX) Efforts Place the Stock Favorably for 2018",
#                 "summary": "We believe management&apos;s well-knitted efforts have helped Skechers (SKX) to make a sharp come back."
#             },
#             {
#                 "title": "Walmart is top brick-and-mortar retail stock",
#                 "summary": "As brick-and-mortar retail stocks struggled in 2017, Walmart remained a top performer, according to U.S. News & World Report .  Walmart gained more than 43 percent this year while competitors like Target, Macy\u2019s and JCPenney lagged.  Target stock is down more than 9 percent, per U.S. News & World Report."
#             },
#             {
#                 "title": "Retail Stocks: Year In Review; What To Shop For In 2018",
#                 "summary": "Shutterstock photo    Retail stocks, those not  named  Amazon ( AMZN ) (up 56% in 2017) or Walmart ( WMT ) (up 43% in 2017), entered 2017 with tons of question marks. Namely, which ones would die and which would survive?  Overall, retailers left investors little to be excited about. If you just bought and held the"
#             },
#             {
#                 "title": "Holiday shopping season wrap-up",
#                 "summary": "Stacey Widlitz of SW Retail Advisors gives her take on the retail sector as 2018 kicks off."
#             },
#             {
#                 "title": "Walmart Stock is a \u2018Dividend Aristocrat\u2019 Worth Watching",
#                 "summary": "Wal-Mart Stores, Inc. (NYSE:WMT) is a discount retail heavyweight that is also a dividend aristocrat.  The dividend aristocrats\u00a0are a select group of 51 companies in the S&P 500 Index, with 25+ consecutive years of dividend increases.  Wal-Mart\u2019s first dividend was $0.05 per share, paid in 1974."
#             }
#         ]
#     }
# }
